# %% [markdown]
# # Training an Object Detection model using Detectron2
#
# This notebook demonstrates how to train a [Detectron2](https://github.com/facebookresearch/detectron2/) model on object detection datasets and produce predictions required to run cleanlab's tutorial on detecting label errors in object detection data.  Note that this notebook fits the model to an entire training set and produces predictions on a held-out validation set. Thus these predictions are only *out-of-sample* for the validation data, and should ideally *only* be used to find mislabeled images amongst the validation set. To instead find mislabeled images amongst an entire dataset, see the analogous notebook in this folder which uses K-fold cross-validation to produce out-of-sample predictions for every image in the dataset.
#
# In object detection data, each image is annotated with multiple bounding boxes.  Each bounding box surrounds a physical object within an image scene, and is annotated with a given class label. Using this labeled data, we train a model to predict the locations and classes of objects in an image. The trained model can subsequently be used to identify mislabeled images, which when corrected, allow you to train an even better model without changing your training code!
#
# Here we will fit a state-of-the-art neural network trained starting from a pretrained [X-101](https://github.com/facebookresearch/detectron2/blob/main/MODEL_ZOO.md#imagenet-pretrained-models) network backbone. First let's import the required packages and download the data.

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cleanlab/examples/blob/master/object_detection/detectron2_training.ipynb)

# %%
# Install PyTorch and torchvision (if needed, adjust versions as necessary)
# !pip install torch torchvision

# Install Detectron2
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'

# Import Detectron2 to verify installation
try:
    import detectron2
    print("Detectron2 was successfully installed!")
except ImportError as e:
    print("Error during Detectron2 installation:", e)
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.17.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 21.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 50.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 56.2 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 938.3 kB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.4 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.2 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.1 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.2 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.7 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.8 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 63.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-_37ibzz0
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-_37ibzz0
#   Resolved https://github.com/facebookresearch/detectron2.git to commit cc9266c2396d5545315e3601027ba4bc28e8c95b
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.0.7)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.4.0)
# Collecting yacs>=0.1.8 (from detectron2==0.6)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (4.66.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.15.2)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2==0.6)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2==0.6)
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf<2.4,>=2.1 (from detectron2==0.6)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.6 MB/s eta 0:00:00
# Collecting hydra-core>=1.1 (from detectron2==0.6)
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 7.9 MB/s eta 0:00:00
# Collecting black (from detectron2==0.6)
#   Downloading black-24.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (24.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.25.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.1)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->detectron2==0.6)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting portalocker (from iopath<0.1.10,>=0.1.7->detectron2==0.6)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (8.1.7)
# Collecting mypy-extensions>=0.4.3 (from black->detectron2==0.6)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2==0.6)
#   Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.2.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.10.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.62.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.5.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Building wheels for collected packages: detectron2, fvcore, antlr4-python3-runtime
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-linux_x86_64.whl size=6149968 sha256=9ed8e33dcb485cb2ab497aea588cb9648151dfaf41ee4ced475bfb074c6bd712
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dnawabd1/wheels/47/e5/15/94c80df2ba85500c5d76599cc307c0a7079d0e221bb6fc4375
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61400 sha256=0dda019401d5be3d6709d4a2d693d24218b897c1f7d7a57696e5891a7a13021f
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=8a21bf54daa80e1a40ca6d8d3b7c8fa85a4ba9bb0ebeb45ff1ceba68e4c6ac57
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built detectron2 fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, omegaconf, mypy-extensions, iopath, hydra-core, black, fvcore, detectron2
# Successfully installed antlr4-python3-runtime-4.9.3 black-24.3.0 detectron2-0.6 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 mypy-extensions-1.0.0 omegaconf-2.3.0 pathspec-0.12.1 portalocker-2.8.2 yacs-0.1.8
# Detectron2 was successfully installed!

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
import pickle
# import some common libraries
import numpy as np
import os, json, cv2, random
from detectron2.data import build_detection_test_loader
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.data.datasets import register_coco_instances

# %%
# !wget -nc "https://cleanlab-public.s3.amazonaws.com/ObjectDetectionBenchmarking/DATASET_annotations/instances_val2017_5labels.json"
# !wget -nc "https://cleanlab-public.s3.amazonaws.com/ObjectDetectionBenchmarking/DATASET_annotations/instances_train2017_5labels.json"
# !wget -nc "https://cleanlab-public.s3.amazonaws.com/ObjectDetectionBenchmarking/tutorial_obj/labels.pkl"
# !wget -nc "http://images.cocodataset.org/zips/val2017.zip" && unzip -q -o val2017.zip
# !wget -nc "http://images.cocodataset.org/zips/train2017.zip" && unzip -q -o train2017.zip
# Out:
# --2024-03-16 10:44:07--  https://cleanlab-public.s3.amazonaws.com/ObjectDetectionBenchmarking/DATASET_annotations/instances_val2017_5labels.json
# Resolving cleanlab-public.s3.amazonaws.com (cleanlab-public.s3.amazonaws.com)... 52.217.50.44, 3.5.21.112, 52.216.176.163, ...
# Connecting to cleanlab-public.s3.amazonaws.com (cleanlab-public.s3.amazonaws.com)|52.217.50.44|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11699868 (11M) [application/json]
# Saving to: ‘instances_val2017_5labels.json’
#
# instances_val2017_5 100%[===================>]  11.16M  13.0MB/s    in 0.9s
#
# 2024-03-16 10:44:09 (13.0 MB/s) - ‘instances_val2017_5labels.json’ saved [11699868/11699868]
#
# --2024-03-16 10:44:09--  https://cleanlab-public.s3.amazonaws.com/ObjectDetectionBenchmarking/DATASET_annotations/instances_train2017_5labels.json
# Resolving cleanlab-public.s3.amazonaws.com (cleanlab-public.s3.amazonaws.com)... 52.217.50.44, 3.5.21.112, 52.216.176.163, ...
# Connecting to cleanlab-public.s3.amazonaws.com (cleanlab-public.s3.amazonaws.com)|52.217.50.44|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 274192049 (261M) [application/json]
# Saving to: ‘instances_train2017_5labels.json’
#
# instances_train2017 100%[===================>] 261.49M  32.9MB/s    in 8.6s
#
# 2024-03-16 10:44:18 (30.2 MB/s) - ‘instances_train2017_5labels.json’ saved [274192049/274192049]
#
# --2024-03-16 10:44:18--  https://cleanlab-public.s3.amazonaws.com/ObjectDetectionBenchmarking/tutorial_obj/labels.pkl
# Resolving cleanlab-public.s3.amazonaws.com (cleanlab-public.s3.amazonaws.com)... 52.216.40.177, 54.231.130.193, 3.5.25.45, ...
# Connecting to cleanlab-public.s3.amazonaws.com (cleanlab-public.s3.amazonaws.com)|52.216.40.177|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 229195 (224K) [binary/octet-stream]
# Saving to: ‘labels.pkl’
#
# labels.pkl          100%[===================>] 223.82K   871KB/s    in 0.3s
#
# 2024-03-16 10:44:19 (871 KB/s) - ‘labels.pkl’ saved [229195/229195]
#
# --2024-03-16 10:44:19--  http://images.cocodataset.org/zips/val2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.200.225, 52.216.60.121, 3.5.25.54, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.200.225|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 815585330 (778M) [application/zip]
# Saving to: ‘val2017.zip’
#
# val2017.zip         100%[===================>] 777.80M  33.3MB/s    in 24s
#
# 2024-03-16 10:44:43 (31.9 MB/s) - ‘val2017.zip’ saved [815585330/815585330]
#
# --2024-03-16 10:44:51--  http://images.cocodataset.org/zips/train2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.142.65, 3.5.27.87, 52.217.114.145, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.142.65|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19336861798 (18G) [application/zip]
# Saving to: ‘train2017.zip’
#
# train2017.zip       100%[===================>]  18.01G  33.1MB/s    in 9m 18s
#
# 2024-03-16 10:54:09 (33.1 MB/s) - ‘train2017.zip’ saved [19336861798/19336861798]

# %% [markdown]
# Before you begin training on a custom dataset, be sure to review the COCO dataset guidelines for formatting your data, which can be found on their [website](https://cocodataset.org/#format-data).

# %% [markdown]
# Here we use a custom dataset named "my_dataset" for training. A subset of the labels ["car", "chair", "cup", "person", and "traffic light"] are used for training and detecting errors in this notebook.

# %%
IMAGE_PATH = "/content/"
TRAIN_PATH = os.path.join(IMAGE_PATH,"train2017")
VAL_PATH = os.path.join(IMAGE_PATH,"val2017")
register_coco_instances("my_dataset_train", {}, "instances_train2017_5labels.json",
                        TRAIN_PATH)
register_coco_instances("my_dataset_val", {}, "instances_val2017_5labels.json",
                        VAL_PATH)

# %% [markdown]
# We define the configuration settings for training an object detection model using Detectron2. The model architecture used in this example is "faster_rcnn_X_101_32x8d_FPN_3x" from the COCO-Detection model zoo. The training data is specified by the "my_dataset_train" dataset and validation data is specified by the "my_dataset_val" dataset which refer to COCO2017 train and val containing only the subset of labels specified before.
#
# Here the number of worker threads is set to 2 and the batch size is set to 2. The learning rate and maximum number of iterations are also specified. You'll want to tinker with these values to get the best performance for your own data.
# The model is initialized from the COCO-Detection model zoo and the output directory for the trained model is created. Finally, this configuration is passed to the DefaultTrainer class for training the object detection model.
#
# <strong>Note:</strong> The number of iterations was set based on [early stopping.](https://en.wikipedia.org/wiki/Early_stopping#:~:text=In%20machine%20learning%2C%20early%20stopping,training%20data%20with%20each%20iteration.)

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("my_dataset_train",)
cfg.DATASETS.TEST = ("my_dataset_val",)
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2  # This is the real "batch size" commonly known to deep learning people
cfg.SOLVER.BASE_LR = 0.00025  # IMPORTANT: pick a good Learning Rate for your dataset
cfg.SOLVER.MAX_ITER = 30000    #
cfg.SOLVER.STEPS = []        # do not decay learning rate
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128   # The "RoIHead batch size".
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 5  # only 5 classes ["car", "chair", "cup", "person", and "traffic light"]
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# %% [markdown]
# ## Train the model

# %%
trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [03/16 11:06:29 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=6, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=20, bias=True)
#     )
#   )
# )
# [03/16 11:06:45 d2.data.datasets.coco]: Loading instances_train2017_5labels.json takes 15.20 seconds.
# [03/16 11:06:47 d2.data.datasets.coco]: Loaded 118287 images in COCO format from instances_train2017_5labels.json
# [03/16 11:06:51 d2.data.build]: Removed 41474 images with no usable annotations. 76813 images left.
# [03/16 11:06:55 d2.data.build]: Distribution of instances among all 5 categories:
# |  category  | #instances   |   category    | #instances   |  category  | #instances   |
# |:----------:|:-------------|:-------------:|:-------------|:----------:|:-------------|
# |    car     | 43533        |     chair     | 38073        |    cup     | 20574        |
# |   person   | 257253       | traffic light | 12842        |            |              |
# |   total    | 372275       |               |              |            |              |
# [03/16 11:06:55 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [03/16 11:06:55 d2.data.build]: Using training sampler TrainingSampler
# [03/16 11:06:55 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [03/16 11:06:55 d2.data.common]: Serializing 76813 elements to byte tensors and concatenating them all ...
# [03/16 11:06:59 d2.data.common]: Serialized dataset takes 224.54 MiB
# [03/16 11:06:59 d2.data.build]: Making batched data loader with batch_size=2
# [03/16 11:07:01 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/faster_rcnn_R_50_FPN_3x/137849458/model_final_280758.pkl ...
# model_final_280758.pkl: 167MB [00:01, 101MB/s]
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (6, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (6,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (20, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (20,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# [03/16 11:07:03 d2.engine.train_loop]: Starting training from iteration 0
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [03/16 11:07:12 d2.utils.events]:  eta: 2:28:48  iter: 19  total_loss: 2.667  loss_cls: 1.787  loss_box_reg: 0.7842  loss_rpn_cls: 0.02757  loss_rpn_loc: 0.03303    time: 0.2657  last_time: 0.1876  data_time: 0.0205  last_data_time: 0.0071   lr: 4.9953e-06  max_mem: 2477M
# [03/16 11:07:26 d2.utils.events]:  eta: 2:18:06  iter: 39  total_loss: 2.514  loss_cls: 1.701  loss_box_reg: 0.7783  loss_rpn_cls: 0.01867  loss_rpn_loc: 0.02611    time: 0.2515  last_time: 0.3093  data_time: 0.0094  last_data_time: 0.0066   lr: 9.9902e-06  max_mem: 2477M
# [03/16 11:07:32 d2.utils.events]:  eta: 2:13:37  iter: 59  total_loss: 2.487  loss_cls: 1.569  loss_box_reg: 0.8207  loss_rpn_cls: 0.02485  loss_rpn_loc: 0.03557    time: 0.2629  last_time: 0.2601  data_time: 0.0098  last_data_time: 0.0148   lr: 1.4985e-05  max_mem: 2477M
# [03/16 11:07:39 d2.utils.events]:  eta: 2:15:49  iter: 79  total_loss: 2.221  loss_cls: 1.402  loss_box_reg: 0.7278  loss_rpn_cls: 0.02362  loss_rpn_loc: 0.02871    time: 0.2767  last_time: 0.2969  data_time: 0.0227  last_data_time: 0.0469   lr: 1.998e-05  max_mem: 2544M
# [03/16 11:07:44 d2.utils.events]:  eta: 2:15:44  iter: 99  total_loss: 1.972  loss_cls: 1.171  loss_box_reg: 0.7734  loss_rpn_cls: 0.01792  loss_rpn_loc: 0.01212    time: 0.2791  last_time: 0.1945  data_time: 0.0134  last_data_time: 0.0073   lr: 2.4975e-05  max_mem: 2544M
# [03/16 11:07:49 d2.utils.events]:  eta: 2:10:56  iter: 119  total_loss: 1.882  loss_cls: 0.9946  loss_box_reg: 0.7486  loss_rpn_cls: 0.02307  loss_rpn_loc: 0.01815    time: 0.2691  last_time: 0.2468  data_time: 0.0093  last_data_time: 0.0270   lr: 2.997e-05  max_mem: 2544M
# [03/16 11:07:56 d2.utils.events]:  eta: 2:16:09  iter: 139  total_loss: 1.376  loss_cls: 0.6714  loss_box_reg: 0.614  loss_rpn_cls: 0.01679  loss_rpn_loc: 0.02695    time: 0.2819  last_time: 0.4023  data_time: 0.0154  last_data_time: 0.0114   lr: 3.4965e-05  max_mem: 2544M
# [03/16 11:08:04 d2.utils.events]:  eta: 2:24:01  iter: 159  total_loss: 1.431  loss_cls: 0.6917  loss_box_reg: 0.7223  loss_rpn_cls: 0.02588  loss_rpn_loc: 0.02316    time: 0.2997  last_time: 0.5683  data_time: 0.0237  last_data_time: 0.0106   lr: 3.996e-05  max_mem: 2544M
# [03/16 11:08:10 d2.utils.events]:  eta: 2:21:57  iter: 179  total_loss: 1.45  loss_cls: 0.6355  loss_box_reg: 0.7724  loss_rpn_cls: 0.01859  loss_rpn_loc: 0.02351    time: 0.2985  last_time: 0.2239  data_time: 0.0102  last_data_time: 0.0119   lr: 4.4955e-05  max_mem: 2544M
# [03/16 11:08:15 d2.utils.events]:  eta: 2:19:08  iter: 199  total_loss: 1.415  loss_cls: 0.6241  loss_box_reg: 0.7675  loss_rpn_cls: 0.01889  loss_rpn_loc: 0.02025    time: 0.2925  last_time: 0.3601  data_time: 0.0081  last_data_time: 0.0125   lr: 4.995e-05  max_mem: 2545M
# [03/16 11:08:21 d2.utils.events]:  eta: 2:19:16  iter: 219  total_loss: 1.258  loss_cls: 0.5676  loss_box_reg: 0.6818  loss_rpn_cls: 0.01611  loss_rpn_loc: 0.01526    time: 0.2932  last_time: 0.3554  data_time: 0.0127  last_data_time: 0.0265   lr: 5.4945e-05  max_mem: 2545M
# [03/16 11:08:29 d2.utils.events]:  eta: 2:24:58  iter: 239  total_loss: 1.317  loss_cls: 0.5321  loss_box_reg: 0.7522  loss_rpn_cls: 0.02565  loss_rpn_loc: 0.02814    time: 0.3024  last_time: 0.3487  data_time: 0.0190  last_data_time: 0.0064   lr: 5.994e-05  max_mem: 2633M
# [03/16 11:08:35 d2.utils.events]:  eta: 2:20:43  iter: 259  total_loss: 1.385  loss_cls: 0.5485  loss_box_reg: 0.7677  loss_rpn_cls: 0.03198  loss_rpn_loc: 0.02852    time: 0.3006  last_time: 0.2601  data_time: 0.0098  last_data_time: 0.0136   lr: 6.4935e-05  max_mem: 2634M
# [03/16 11:08:42 d2.utils.events]:  eta: 2:22:37  iter: 279  total_loss: 1.347  loss_cls: 0.5118  loss_box_reg: 0.7921  loss_rpn_cls: 0.0235  loss_rpn_loc: 0.01627    time: 0.3040  last_time: 0.5034  data_time: 0.0126  last_data_time: 0.0052   lr: 6.993e-05  max_mem: 2634M
# [03/16 11:08:50 d2.utils.events]:  eta: 2:26:10  iter: 299  total_loss: 1.391  loss_cls: 0.5246  loss_box_reg: 0.7825  loss_rpn_cls: 0.02004  loss_rpn_loc: 0.02166    time: 0.3101  last_time: 0.2994  data_time: 0.0159  last_data_time: 0.0081   lr: 7.4925e-05  max_mem: 2634M
# [03/16 11:08:55 d2.utils.events]:  eta: 2:24:44  iter: 319  total_loss: 1.283  loss_cls: 0.5447  loss_box_reg: 0.7095  loss_rpn_cls: 0.02178  loss_rpn_loc: 0.01832    time: 0.3088  last_time: 0.2920  data_time: 0.0078  last_data_time: 0.0071   lr: 7.992e-05  max_mem: 2634M
# [03/16 11:09:03 d2.utils.events]:  eta: 2:27:01  iter: 339  total_loss: 1.257  loss_cls: 0.4056  loss_box_reg: 0.7816  loss_rpn_cls: 0.02215  loss_rpn_loc: 0.02852    time: 0.3123  last_time: 0.3916  data_time: 0.0136  last_data_time: 0.0210   lr: 8.4915e-05  max_mem: 2634M
# [03/16 11:09:11 d2.utils.events]:  eta: 2:28:03  iter: 359  total_loss: 1.144  loss_cls: 0.3689  loss_box_reg: 0.6733  loss_rpn_cls: 0.01232  loss_rpn_loc: 0.01946    time: 0.3165  last_time: 0.3162  data_time: 0.0164  last_data_time: 0.0305   lr: 8.991e-05  max_mem: 2634M
# [03/16 11:09:17 d2.utils.events]:  eta: 2:27:51  iter: 379  total_loss: 1.343  loss_cls: 0.4941  loss_box_reg: 0.7991  loss_rpn_cls: 0.02061  loss_rpn_loc: 0.02736    time: 0.3158  last_time: 0.2812  data_time: 0.0083  last_data_time: 0.0041   lr: 9.4905e-05  max_mem: 2634M
# [03/16 11:09:25 d2.utils.events]:  eta: 2:29:50  iter: 399  total_loss: 1.159  loss_cls: 0.4331  loss_box_reg: 0.6474  loss_rpn_cls: 0.02234  loss_rpn_loc: 0.03144    time: 0.3202  last_time: 0.4346  data_time: 0.0146  last_data_time: 0.0253   lr: 9.99e-05  max_mem: 2634M
# [03/16 11:09:32 d2.utils.events]:  eta: 2:30:35  iter: 419  total_loss: 1.088  loss_cls: 0.3801  loss_box_reg: 0.6198  loss_rpn_cls: 0.0119  loss_rpn_loc: 0.007638    time: 0.3215  last_time: 0.3075  data_time: 0.0132  last_data_time: 0.0073   lr: 0.0001049  max_mem: 2634M
# [03/16 11:09:38 d2.utils.events]:  eta: 2:30:29  iter: 439  total_loss: 1.099  loss_cls: 0.3636  loss_box_reg: 0.6995  loss_rpn_cls: 0.01414  loss_rpn_loc: 0.02559    time: 0.3215  last_time: 0.3831  data_time: 0.0089  last_data_time: 0.0097   lr: 0.00010989  max_mem: 2634M
# [03/16 11:09:47 d2.utils.events]:  eta: 2:31:41  iter: 459  total_loss: 1.142  loss_cls: 0.3601  loss_box_reg: 0.7094  loss_rpn_cls: 0.02718  loss_rpn_loc: 0.03596    time: 0.3279  last_time: 0.4344  data_time: 0.0145  last_data_time: 0.0077   lr: 0.00011489  max_mem: 2634M
# [03/16 11:09:54 d2.utils.events]:  eta: 2:31:22  iter: 479  total_loss: 0.8708  loss_cls: 0.2589  loss_box_reg: 0.5208  loss_rpn_cls: 0.01458  loss_rpn_loc: 0.02203    time: 0.3273  last_time: 0.2993  data_time: 0.0083  last_data_time: 0.0067   lr: 0.00011988  max_mem: 2634M
# [03/16 11:10:01 d2.utils.events]:  eta: 2:32:11  iter: 499  total_loss: 0.8041  loss_cls: 0.2156  loss_box_reg: 0.5232  loss_rpn_cls: 0.01187  loss_rpn_loc: 0.01865    time: 0.3285  last_time: 0.4602  data_time: 0.0114  last_data_time: 0.0189   lr: 0.00012488  max_mem: 2634M
# [03/16 11:10:09 d2.utils.events]:  eta: 2:34:01  iter: 519  total_loss: 1.014  loss_cls: 0.3274  loss_box_reg: 0.5996  loss_rpn_cls: 0.01644  loss_rpn_loc: 0.01779    time: 0.3320  last_time: 0.3244  data_time: 0.0191  last_data_time: 0.0167   lr: 0.00012987  max_mem: 2634M
# [03/16 11:10:18 d2.utils.events]:  eta: 2:34:51  iter: 539  total_loss: 0.924  loss_cls: 0.3158  loss_box_reg: 0.5607  loss_rpn_cls: 0.0218  loss_rpn_loc: 0.01722    time: 0.3351  last_time: 0.5023  data_time: 0.0143  last_data_time: 0.0328   lr: 0.00013487  max_mem: 2634M
# [03/16 11:10:28 d2.utils.events]:  eta: 2:36:00  iter: 559  total_loss: 0.922  loss_cls: 0.3343  loss_box_reg: 0.5171  loss_rpn_cls: 0.01978  loss_rpn_loc: 0.01691    time: 0.3413  last_time: 0.4425  data_time: 0.0230  last_data_time: 0.0220   lr: 0.00013986  max_mem: 2634M
# [03/16 11:10:35 d2.utils.events]:  eta: 2:36:49  iter: 579  total_loss: 0.7802  loss_cls: 0.2778  loss_box_reg: 0.4963  loss_rpn_cls: 0.02375  loss_rpn_loc: 0.02484    time: 0.3424  last_time: 0.3452  data_time: 0.0142  last_data_time: 0.0077   lr: 0.00014486  max_mem: 2634M
# [03/16 11:10:42 d2.utils.events]:  eta: 2:37:26  iter: 599  total_loss: 0.6465  loss_cls: 0.1996  loss_box_reg: 0.4006  loss_rpn_cls: 0.02025  loss_rpn_loc: 0.0187    time: 0.3424  last_time: 0.4096  data_time: 0.0081  last_data_time: 0.0125   lr: 0.00014985  max_mem: 2636M
# [03/16 11:10:51 d2.utils.events]:  eta: 2:39:37  iter: 619  total_loss: 0.6283  loss_cls: 0.1749  loss_box_reg: 0.4148  loss_rpn_cls: 0.01836  loss_rpn_loc: 0.01525    time: 0.3462  last_time: 0.4268  data_time: 0.0168  last_data_time: 0.0195   lr: 0.00015485  max_mem: 2636M
# [03/16 11:10:58 d2.utils.events]:  eta: 2:39:33  iter: 639  total_loss: 0.8083  loss_cls: 0.284  loss_box_reg: 0.445  loss_rpn_cls: 0.02514  loss_rpn_loc: 0.0303    time: 0.3458  last_time: 0.3215  data_time: 0.0073  last_data_time: 0.0046   lr: 0.00015984  max_mem: 2636M
# [03/16 11:11:06 d2.utils.events]:  eta: 2:40:01  iter: 659  total_loss: 0.845  loss_cls: 0.3156  loss_box_reg: 0.5272  loss_rpn_cls: 0.02001  loss_rpn_loc: 0.02622    time: 0.3477  last_time: 0.4384  data_time: 0.0133  last_data_time: 0.0058   lr: 0.00016484  max_mem: 2636M
# [03/16 11:11:14 d2.utils.events]:  eta: 2:40:40  iter: 679  total_loss: 0.8443  loss_cls: 0.2923  loss_box_reg: 0.519  loss_rpn_cls: 0.01493  loss_rpn_loc: 0.02287    time: 0.3494  last_time: 0.3354  data_time: 0.0170  last_data_time: 0.0154   lr: 0.00016983  max_mem: 2636M
# [03/16 11:11:21 d2.utils.events]:  eta: 2:40:53  iter: 699  total_loss: 0.7055  loss_cls: 0.2169  loss_box_reg: 0.4495  loss_rpn_cls: 0.01726  loss_rpn_loc: 0.02875    time: 0.3493  last_time: 0.4345  data_time: 0.0075  last_data_time: 0.0076   lr: 0.00017483  max_mem: 2636M
# [03/16 11:11:31 d2.utils.events]:  eta: 2:41:46  iter: 719  total_loss: 0.6318  loss_cls: 0.193  loss_box_reg: 0.3871  loss_rpn_cls: 0.01398  loss_rpn_loc: 0.01573    time: 0.3524  last_time: 0.3930  data_time: 0.0197  last_data_time: 0.0050   lr: 0.00017982  max_mem: 2636M
# [03/16 11:11:38 d2.utils.events]:  eta: 2:42:41  iter: 739  total_loss: 0.8157  loss_cls: 0.2396  loss_box_reg: 0.4336  loss_rpn_cls: 0.01285  loss_rpn_loc: 0.01876    time: 0.3525  last_time: 0.3554  data_time: 0.0076  last_data_time: 0.0100   lr: 0.00018482  max_mem: 2636M
# [03/16 11:11:47 d2.utils.events]:  eta: 2:43:26  iter: 759  total_loss: 0.5799  loss_cls: 0.1683  loss_box_reg: 0.3747  loss_rpn_cls: 0.01177  loss_rpn_loc: 0.03216    time: 0.3550  last_time: 0.5001  data_time: 0.0138  last_data_time: 0.0268   lr: 0.00018981  max_mem: 2636M
# [03/16 11:11:55 d2.utils.events]:  eta: 2:43:52  iter: 779  total_loss: 0.7195  loss_cls: 0.2373  loss_box_reg: 0.4005  loss_rpn_cls: 0.01811  loss_rpn_loc: 0.03046    time: 0.3566  last_time: 0.3353  data_time: 0.0131  last_data_time: 0.0062   lr: 0.00019481  max_mem: 2636M
# [03/16 11:12:03 d2.utils.events]:  eta: 2:44:18  iter: 799  total_loss: 0.694  loss_cls: 0.2226  loss_box_reg: 0.4109  loss_rpn_cls: 0.01324  loss_rpn_loc: 0.02171    time: 0.3577  last_time: 0.4472  data_time: 0.0116  last_data_time: 0.0075   lr: 0.0001998  max_mem: 2636M
# [03/16 11:12:12 d2.utils.events]:  eta: 2:45:34  iter: 819  total_loss: 0.7076  loss_cls: 0.2204  loss_box_reg: 0.3944  loss_rpn_cls: 0.02701  loss_rpn_loc: 0.02906    time: 0.3600  last_time: 0.3711  data_time: 0.0183  last_data_time: 0.0177   lr: 0.0002048  max_mem: 2636M
# [03/16 11:12:19 d2.utils.events]:  eta: 2:46:56  iter: 839  total_loss: 0.5851  loss_cls: 0.1683  loss_box_reg: 0.3865  loss_rpn_cls: 0.01461  loss_rpn_loc: 0.01665    time: 0.3601  last_time: 0.3990  data_time: 0.0085  last_data_time: 0.0088   lr: 0.00020979  max_mem: 2636M
# [03/16 11:12:29 d2.utils.events]:  eta: 2:47:31  iter: 859  total_loss: 0.7922  loss_cls: 0.212  loss_box_reg: 0.4616  loss_rpn_cls: 0.01838  loss_rpn_loc: 0.01752    time: 0.3629  last_time: 0.4964  data_time: 0.0153  last_data_time: 0.0249   lr: 0.00021479  max_mem: 2636M
# [03/16 11:12:37 d2.utils.events]:  eta: 2:48:09  iter: 879  total_loss: 0.6427  loss_cls: 0.1996  loss_box_reg: 0.3325  loss_rpn_cls: 0.01642  loss_rpn_loc: 0.03181    time: 0.3641  last_time: 0.4564  data_time: 0.0110  last_data_time: 0.0079   lr: 0.00021978  max_mem: 2636M
# [03/16 11:12:49 d2.utils.events]:  eta: 2:49:53  iter: 899  total_loss: 0.5987  loss_cls: 0.2042  loss_box_reg: 0.3714  loss_rpn_cls: 0.01569  loss_rpn_loc: 0.01507    time: 0.3687  last_time: 0.5166  data_time: 0.0230  last_data_time: 0.0051   lr: 0.00022478  max_mem: 2636M
# [03/16 11:12:58 d2.utils.events]:  eta: 2:50:37  iter: 919  total_loss: 0.5383  loss_cls: 0.1647  loss_box_reg: 0.3753  loss_rpn_cls: 0.01343  loss_rpn_loc: 0.01544    time: 0.3703  last_time: 0.3508  data_time: 0.0126  last_data_time: 0.0039   lr: 0.00022977  max_mem: 2636M
# [03/16 11:13:06 d2.utils.events]:  eta: 2:51:27  iter: 939  total_loss: 0.6029  loss_cls: 0.1759  loss_box_reg: 0.4457  loss_rpn_cls: 0.01023  loss_rpn_loc: 0.01075    time: 0.3710  last_time: 0.4986  data_time: 0.0109  last_data_time: 0.0299   lr: 0.00023477  max_mem: 2636M
# [03/16 11:13:15 d2.utils.events]:  eta: 2:52:11  iter: 959  total_loss: 0.5445  loss_cls: 0.1513  loss_box_reg: 0.3477  loss_rpn_cls: 0.01101  loss_rpn_loc: 0.01466    time: 0.3732  last_time: 0.3847  data_time: 0.0177  last_data_time: 0.0100   lr: 0.00023976  max_mem: 2636M
# [03/16 11:13:23 d2.utils.events]:  eta: 2:53:08  iter: 979  total_loss: 0.7021  loss_cls: 0.2042  loss_box_reg: 0.46  loss_rpn_cls: 0.0152  loss_rpn_loc: 0.02527    time: 0.3734  last_time: 0.4041  data_time: 0.0091  last_data_time: 0.0092   lr: 0.00024476  max_mem: 2636M
# [03/16 11:13:33 d2.utils.events]:  eta: 2:54:52  iter: 999  total_loss: 0.6571  loss_cls: 0.1872  loss_box_reg: 0.3995  loss_rpn_cls: 0.01305  loss_rpn_loc: 0.04136    time: 0.3757  last_time: 0.4856  data_time: 0.0176  last_data_time: 0.0228   lr: 0.00024975  max_mem: 2636M
# [03/16 11:13:41 d2.utils.events]:  eta: 2:56:50  iter: 1019  total_loss: 0.5897  loss_cls: 0.1639  loss_box_reg: 0.3689  loss_rpn_cls: 0.01852  loss_rpn_loc: 0.01685    time: 0.3761  last_time: 0.4197  data_time: 0.0083  last_data_time: 0.0102   lr: 0.00025  max_mem: 2636M
# [03/16 11:13:50 d2.utils.events]:  eta: 2:58:30  iter: 1039  total_loss: 0.6489  loss_cls: 0.1784  loss_box_reg: 0.3719  loss_rpn_cls: 0.01921  loss_rpn_loc: 0.04586    time: 0.3780  last_time: 0.4433  data_time: 0.0142  last_data_time: 0.0062   lr: 0.00025  max_mem: 2636M
# [03/16 11:13:58 d2.utils.events]:  eta: 2:59:33  iter: 1059  total_loss: 0.6085  loss_cls: 0.2319  loss_box_reg: 0.3524  loss_rpn_cls: 0.03007  loss_rpn_loc: 0.01935    time: 0.3787  last_time: 0.3784  data_time: 0.0096  last_data_time: 0.0064   lr: 0.00025  max_mem: 2636M
# [03/16 11:14:07 d2.utils.events]:  eta: 3:01:04  iter: 1079  total_loss: 0.6984  loss_cls: 0.1757  loss_box_reg: 0.3731  loss_rpn_cls: 0.01656  loss_rpn_loc: 0.02717    time: 0.3799  last_time: 0.5217  data_time: 0.0107  last_data_time: 0.0075   lr: 0.00025  max_mem: 2636M
# [03/16 11:14:16 d2.utils.events]:  eta: 3:02:18  iter: 1099  total_loss: 0.6141  loss_cls: 0.1686  loss_box_reg: 0.3896  loss_rpn_cls: 0.01336  loss_rpn_loc: 0.02909    time: 0.3812  last_time: 0.4055  data_time: 0.0124  last_data_time: 0.0067   lr: 0.00025  max_mem: 2636M
# [03/16 11:14:25 d2.utils.events]:  eta: 3:03:51  iter: 1119  total_loss: 0.5164  loss_cls: 0.1598  loss_box_reg: 0.3485  loss_rpn_cls: 0.01126  loss_rpn_loc: 0.01568    time: 0.3822  last_time: 0.6581  data_time: 0.0092  last_data_time: 0.0177   lr: 0.00025  max_mem: 2636M
# [03/16 11:14:35 d2.utils.events]:  eta: 3:04:26  iter: 1139  total_loss: 0.6  loss_cls: 0.169  loss_box_reg: 0.3608  loss_rpn_cls: 0.02202  loss_rpn_loc: 0.03334    time: 0.3838  last_time: 0.3738  data_time: 0.0187  last_data_time: 0.0061   lr: 0.00025  max_mem: 2636M
# [03/16 11:14:43 d2.utils.events]:  eta: 3:04:19  iter: 1159  total_loss: 0.5617  loss_cls: 0.1694  loss_box_reg: 0.366  loss_rpn_cls: 0.01575  loss_rpn_loc: 0.01619    time: 0.3842  last_time: 0.4864  data_time: 0.0102  last_data_time: 0.0261   lr: 0.00025  max_mem: 2636M
# [03/16 11:14:53 d2.utils.events]:  eta: 3:05:54  iter: 1179  total_loss: 0.6676  loss_cls: 0.1794  loss_box_reg: 0.3736  loss_rpn_cls: 0.01083  loss_rpn_loc: 0.01861    time: 0.3862  last_time: 0.3636  data_time: 0.0141  last_data_time: 0.0047   lr: 0.00025  max_mem: 2636M
# [03/16 11:15:02 d2.utils.events]:  eta: 3:07:10  iter: 1199  total_loss: 0.6074  loss_cls: 0.192  loss_box_reg: 0.3374  loss_rpn_cls: 0.03162  loss_rpn_loc: 0.03396    time: 0.3872  last_time: 0.5241  data_time: 0.0112  last_data_time: 0.0293   lr: 0.00025  max_mem: 2636M
# [03/16 11:15:13 d2.utils.events]:  eta: 3:08:23  iter: 1219  total_loss: 0.6711  loss_cls: 0.2091  loss_box_reg: 0.411  loss_rpn_cls: 0.02519  loss_rpn_loc: 0.02424    time: 0.3902  last_time: 0.4508  data_time: 0.0207  last_data_time: 0.0077   lr: 0.00025  max_mem: 2636M
# [03/16 11:15:22 d2.utils.events]:  eta: 3:09:01  iter: 1239  total_loss: 0.4545  loss_cls: 0.1128  loss_box_reg: 0.3198  loss_rpn_cls: 0.007605  loss_rpn_loc: 0.01521    time: 0.3910  last_time: 0.3929  data_time: 0.0128  last_data_time: 0.0065   lr: 0.00025  max_mem: 2636M
# [03/16 11:15:31 d2.utils.events]:  eta: 3:11:04  iter: 1259  total_loss: 0.646  loss_cls: 0.1856  loss_box_reg: 0.3735  loss_rpn_cls: 0.02356  loss_rpn_loc: 0.03256    time: 0.3920  last_time: 0.6547  data_time: 0.0097  last_data_time: 0.0015   lr: 0.00025  max_mem: 2636M
# [03/16 11:15:40 d2.utils.events]:  eta: 3:12:06  iter: 1279  total_loss: 0.5998  loss_cls: 0.1723  loss_box_reg: 0.3838  loss_rpn_cls: 0.0159  loss_rpn_loc: 0.02361    time: 0.3931  last_time: 0.4335  data_time: 0.0144  last_data_time: 0.0131   lr: 0.00025  max_mem: 2636M
# [03/16 11:15:49 d2.utils.events]:  eta: 3:13:03  iter: 1299  total_loss: 0.5062  loss_cls: 0.1166  loss_box_reg: 0.3509  loss_rpn_cls: 0.01485  loss_rpn_loc: 0.009974    time: 0.3939  last_time: 0.5093  data_time: 0.0105  last_data_time: 0.0075   lr: 0.00025  max_mem: 2636M
# [03/16 11:15:59 d2.utils.events]:  eta: 3:14:21  iter: 1319  total_loss: 0.5987  loss_cls: 0.1868  loss_box_reg: 0.3477  loss_rpn_cls: 0.02353  loss_rpn_loc: 0.03006    time: 0.3953  last_time: 0.3992  data_time: 0.0169  last_data_time: 0.0067   lr: 0.00025  max_mem: 2636M
# [03/16 11:16:08 d2.utils.events]:  eta: 3:14:27  iter: 1339  total_loss: 0.4993  loss_cls: 0.1541  loss_box_reg: 0.3187  loss_rpn_cls: 0.01312  loss_rpn_loc: 0.02563    time: 0.3957  last_time: 0.5331  data_time: 0.0099  last_data_time: 0.0274   lr: 0.00025  max_mem: 2636M
# [03/16 11:16:18 d2.utils.events]:  eta: 3:16:08  iter: 1359  total_loss: 0.5161  loss_cls: 0.1366  loss_box_reg: 0.3244  loss_rpn_cls: 0.01182  loss_rpn_loc: 0.01649    time: 0.3973  last_time: 0.4339  data_time: 0.0144  last_data_time: 0.0074   lr: 0.00025  max_mem: 2636M
# [03/16 11:16:26 d2.utils.events]:  eta: 3:16:47  iter: 1379  total_loss: 0.6923  loss_cls: 0.2088  loss_box_reg: 0.3904  loss_rpn_cls: 0.02  loss_rpn_loc: 0.04324    time: 0.3975  last_time: 0.5105  data_time: 0.0084  last_data_time: 0.0086   lr: 0.00025  max_mem: 2636M
# [03/16 11:16:36 d2.utils.events]:  eta: 3:18:09  iter: 1399  total_loss: 0.4337  loss_cls: 0.126  loss_box_reg: 0.2715  loss_rpn_cls: 0.01239  loss_rpn_loc: 0.01971    time: 0.3992  last_time: 0.4006  data_time: 0.0173  last_data_time: 0.0071   lr: 0.00025  max_mem: 2636M
# [03/16 11:16:44 d2.utils.events]:  eta: 3:17:52  iter: 1419  total_loss: 0.5067  loss_cls: 0.1457  loss_box_reg: 0.3225  loss_rpn_cls: 0.01017  loss_rpn_loc: 0.01404    time: 0.3992  last_time: 0.4266  data_time: 0.0080  last_data_time: 0.0262   lr: 0.00025  max_mem: 2636M
# [03/16 11:16:55 d2.utils.events]:  eta: 3:19:42  iter: 1439  total_loss: 0.5977  loss_cls: 0.1662  loss_box_reg: 0.3185  loss_rpn_cls: 0.01238  loss_rpn_loc: 0.02709    time: 0.4010  last_time: 0.4592  data_time: 0.0178  last_data_time: 0.0041   lr: 0.00025  max_mem: 2636M
# [03/16 11:17:03 d2.utils.events]:  eta: 3:18:55  iter: 1459  total_loss: 0.5815  loss_cls: 0.1686  loss_box_reg: 0.3511  loss_rpn_cls: 0.01385  loss_rpn_loc: 0.02026    time: 0.4013  last_time: 0.4114  data_time: 0.0090  last_data_time: 0.0075   lr: 0.00025  max_mem: 2636M
# [03/16 11:17:14 d2.utils.events]:  eta: 3:21:03  iter: 1479  total_loss: 0.5055  loss_cls: 0.1695  loss_box_reg: 0.3051  loss_rpn_cls: 0.01718  loss_rpn_loc: 0.04665    time: 0.4028  last_time: 0.5323  data_time: 0.0173  last_data_time: 0.0118   lr: 0.00025  max_mem: 2636M
# [03/16 11:17:22 d2.utils.events]:  eta: 3:20:55  iter: 1499  total_loss: 0.5481  loss_cls: 0.145  loss_box_reg: 0.3224  loss_rpn_cls: 0.01686  loss_rpn_loc: 0.02037    time: 0.4029  last_time: 0.4170  data_time: 0.0089  last_data_time: 0.0112   lr: 0.00025  max_mem: 2636M
# [03/16 11:17:34 d2.utils.events]:  eta: 3:22:19  iter: 1519  total_loss: 0.6735  loss_cls: 0.1831  loss_box_reg: 0.397  loss_rpn_cls: 0.0314  loss_rpn_loc: 0.03748    time: 0.4053  last_time: 0.6450  data_time: 0.0224  last_data_time: 0.0309   lr: 0.00025  max_mem: 2636M
# [03/16 11:17:45 d2.utils.events]:  eta: 3:22:36  iter: 1539  total_loss: 0.5929  loss_cls: 0.1674  loss_box_reg: 0.3425  loss_rpn_cls: 0.01908  loss_rpn_loc: 0.0147    time: 0.4072  last_time: 0.4389  data_time: 0.0191  last_data_time: 0.0090   lr: 0.00025  max_mem: 2636M
# [03/16 11:17:54 d2.utils.events]:  eta: 3:22:02  iter: 1559  total_loss: 0.6174  loss_cls: 0.1744  loss_box_reg: 0.3421  loss_rpn_cls: 0.01259  loss_rpn_loc: 0.03108    time: 0.4079  last_time: 0.5270  data_time: 0.0115  last_data_time: 0.0211   lr: 0.00025  max_mem: 2636M
# [03/16 11:18:04 d2.utils.events]:  eta: 3:22:22  iter: 1579  total_loss: 0.4977  loss_cls: 0.1589  loss_box_reg: 0.3002  loss_rpn_cls: 0.01341  loss_rpn_loc: 0.01296    time: 0.4090  last_time: 0.4035  data_time: 0.0174  last_data_time: 0.0069   lr: 0.00025  max_mem: 2636M
# [03/16 11:18:13 d2.utils.events]:  eta: 3:23:16  iter: 1599  total_loss: 0.6574  loss_cls: 0.1974  loss_box_reg: 0.3141  loss_rpn_cls: 0.03021  loss_rpn_loc: 0.02899    time: 0.4096  last_time: 0.5861  data_time: 0.0105  last_data_time: 0.0097   lr: 0.00025  max_mem: 2636M
# [03/16 11:18:23 d2.utils.events]:  eta: 3:23:08  iter: 1619  total_loss: 0.5337  loss_cls: 0.1602  loss_box_reg: 0.3339  loss_rpn_cls: 0.01416  loss_rpn_loc: 0.01491    time: 0.4105  last_time: 0.4181  data_time: 0.0136  last_data_time: 0.0067   lr: 0.00025  max_mem: 2636M
# [03/16 11:18:31 d2.utils.events]:  eta: 3:23:43  iter: 1639  total_loss: 0.6169  loss_cls: 0.1783  loss_box_reg: 0.3285  loss_rpn_cls: 0.02478  loss_rpn_loc: 0.03586    time: 0.4109  last_time: 0.5354  data_time: 0.0092  last_data_time: 0.0141   lr: 0.00025  max_mem: 2636M
# [03/16 11:18:42 d2.utils.events]:  eta: 3:24:46  iter: 1659  total_loss: 0.7492  loss_cls: 0.2114  loss_box_reg: 0.365  loss_rpn_cls: 0.0271  loss_rpn_loc: 0.03705    time: 0.4121  last_time: 0.4508  data_time: 0.0171  last_data_time: 0.0098   lr: 0.00025  max_mem: 2636M
# [03/16 11:18:50 d2.utils.events]:  eta: 3:24:30  iter: 1679  total_loss: 0.6628  loss_cls: 0.1582  loss_box_reg: 0.4213  loss_rpn_cls: 0.01773  loss_rpn_loc: 0.02176    time: 0.4123  last_time: 0.5276  data_time: 0.0093  last_data_time: 0.0145   lr: 0.00025  max_mem: 2636M
# [03/16 11:19:01 d2.utils.events]:  eta: 3:25:35  iter: 1699  total_loss: 0.6552  loss_cls: 0.1821  loss_box_reg: 0.3597  loss_rpn_cls: 0.01891  loss_rpn_loc: 0.02855    time: 0.4136  last_time: 0.4074  data_time: 0.0190  last_data_time: 0.0046   lr: 0.00025  max_mem: 2636M
# [03/16 11:19:09 d2.utils.events]:  eta: 3:24:49  iter: 1719  total_loss: 0.61  loss_cls: 0.1465  loss_box_reg: 0.3753  loss_rpn_cls: 0.01252  loss_rpn_loc: 0.02595    time: 0.4139  last_time: 0.5232  data_time: 0.0093  last_data_time: 0.0212   lr: 0.00025  max_mem: 2636M
# [03/16 11:19:20 d2.utils.events]:  eta: 3:26:38  iter: 1739  total_loss: 0.5004  loss_cls: 0.1341  loss_box_reg: 0.3173  loss_rpn_cls: 0.0176  loss_rpn_loc: 0.03274    time: 0.4152  last_time: 0.4413  data_time: 0.0193  last_data_time: 0.0208   lr: 0.00025  max_mem: 2636M
# [03/16 11:19:29 d2.utils.events]:  eta: 3:26:11  iter: 1759  total_loss: 0.5877  loss_cls: 0.1703  loss_box_reg: 0.3412  loss_rpn_cls: 0.0168  loss_rpn_loc: 0.01194    time: 0.4154  last_time: 0.5429  data_time: 0.0085  last_data_time: 0.0072   lr: 0.00025  max_mem: 2636M
# [03/16 11:19:39 d2.utils.events]:  eta: 3:27:30  iter: 1779  total_loss: 0.6239  loss_cls: 0.1772  loss_box_reg: 0.3608  loss_rpn_cls: 0.01906  loss_rpn_loc: 0.02949    time: 0.4166  last_time: 0.4430  data_time: 0.0178  last_data_time: 0.0091   lr: 0.00025  max_mem: 2636M
# [03/16 11:19:48 d2.utils.events]:  eta: 3:27:18  iter: 1799  total_loss: 0.47  loss_cls: 0.1341  loss_box_reg: 0.295  loss_rpn_cls: 0.006529  loss_rpn_loc: 0.01536    time: 0.4167  last_time: 0.5639  data_time: 0.0084  last_data_time: 0.0069   lr: 0.00025  max_mem: 2636M
# [03/16 11:20:01 d2.utils.events]:  eta: 3:28:08  iter: 1819  total_loss: 0.5593  loss_cls: 0.1694  loss_box_reg: 0.2934  loss_rpn_cls: 0.01937  loss_rpn_loc: 0.03491    time: 0.4195  last_time: 0.6067  data_time: 0.0189  last_data_time: 0.0211   lr: 0.00025  max_mem: 2636M
# [03/16 11:20:11 d2.utils.events]:  eta: 3:28:37  iter: 1839  total_loss: 0.5268  loss_cls: 0.1542  loss_box_reg: 0.3045  loss_rpn_cls: 0.0147  loss_rpn_loc: 0.01268    time: 0.4202  last_time: 0.4323  data_time: 0.0144  last_data_time: 0.0066   lr: 0.00025  max_mem: 2636M
# [03/16 11:20:20 d2.utils.events]:  eta: 3:27:51  iter: 1859  total_loss: 0.5874  loss_cls: 0.1709  loss_box_reg: 0.2964  loss_rpn_cls: 0.02596  loss_rpn_loc: 0.02374    time: 0.4208  last_time: 0.6162  data_time: 0.0148  last_data_time: 0.0320   lr: 0.00025  max_mem: 2637M
# [03/16 11:20:30 d2.utils.events]:  eta: 3:27:50  iter: 1879  total_loss: 0.5999  loss_cls: 0.1739  loss_box_reg: 0.3885  loss_rpn_cls: 0.008891  loss_rpn_loc: 0.03263    time: 0.4214  last_time: 0.4113  data_time: 0.0121  last_data_time: 0.0040   lr: 0.00025  max_mem: 2637M
# [03/16 11:20:40 d2.utils.events]:  eta: 3:27:16  iter: 1899  total_loss: 0.6052  loss_cls: 0.1815  loss_box_reg: 0.346  loss_rpn_cls: 0.01293  loss_rpn_loc: 0.01267    time: 0.4222  last_time: 0.5313  data_time: 0.0125  last_data_time: 0.0056   lr: 0.00025  max_mem: 2637M
# [03/16 11:20:49 d2.utils.events]:  eta: 3:27:17  iter: 1919  total_loss: 0.6642  loss_cls: 0.1918  loss_box_reg: 0.3548  loss_rpn_cls: 0.01639  loss_rpn_loc: 0.02096    time: 0.4228  last_time: 0.4220  data_time: 0.0111  last_data_time: 0.0043   lr: 0.00025  max_mem: 2637M
# [03/16 11:20:59 d2.utils.events]:  eta: 3:27:53  iter: 1939  total_loss: 0.5673  loss_cls: 0.1654  loss_box_reg: 0.3462  loss_rpn_cls: 0.01951  loss_rpn_loc: 0.0257    time: 0.4235  last_time: 0.5326  data_time: 0.0124  last_data_time: 0.0068   lr: 0.00025  max_mem: 2637M
# [03/16 11:21:09 d2.utils.events]:  eta: 3:27:38  iter: 1959  total_loss: 0.5348  loss_cls: 0.1522  loss_box_reg: 0.347  loss_rpn_cls: 0.01382  loss_rpn_loc: 0.01162    time: 0.4243  last_time: 0.4554  data_time: 0.0143  last_data_time: 0.0075   lr: 0.00025  max_mem: 2637M
# [03/16 11:21:20 d2.utils.events]:  eta: 3:29:41  iter: 1979  total_loss: 0.6559  loss_cls: 0.1821  loss_box_reg: 0.4252  loss_rpn_cls: 0.01511  loss_rpn_loc: 0.04191    time: 0.4252  last_time: 0.5666  data_time: 0.0145  last_data_time: 0.0258   lr: 0.00025  max_mem: 2637M
# [03/16 11:21:29 d2.utils.events]:  eta: 3:29:18  iter: 1999  total_loss: 0.3741  loss_cls: 0.1133  loss_box_reg: 0.2275  loss_rpn_cls: 0.009894  loss_rpn_loc: 0.008139    time: 0.4257  last_time: 0.4618  data_time: 0.0135  last_data_time: 0.0185   lr: 0.00025  max_mem: 2637M
# [03/16 11:21:40 d2.utils.events]:  eta: 3:31:03  iter: 2019  total_loss: 0.5474  loss_cls: 0.1871  loss_box_reg: 0.2861  loss_rpn_cls: 0.009549  loss_rpn_loc: 0.02557    time: 0.4266  last_time: 0.6309  data_time: 0.0154  last_data_time: 0.0416   lr: 0.00025  max_mem: 2637M
# [03/16 11:21:49 d2.utils.events]:  eta: 3:30:07  iter: 2039  total_loss: 0.5197  loss_cls: 0.1538  loss_box_reg: 0.3367  loss_rpn_cls: 0.01078  loss_rpn_loc: 0.02463    time: 0.4271  last_time: 0.4319  data_time: 0.0111  last_data_time: 0.0114   lr: 0.00025  max_mem: 2637M
# [03/16 11:21:59 d2.utils.events]:  eta: 3:31:29  iter: 2059  total_loss: 0.5495  loss_cls: 0.1255  loss_box_reg: 0.3274  loss_rpn_cls: 0.01684  loss_rpn_loc: 0.03014    time: 0.4279  last_time: 0.4640  data_time: 0.0134  last_data_time: 0.0056   lr: 0.00025  max_mem: 2637M
# [03/16 11:22:09 d2.utils.events]:  eta: 3:31:02  iter: 2079  total_loss: 0.4701  loss_cls: 0.1429  loss_box_reg: 0.2795  loss_rpn_cls: 0.01231  loss_rpn_loc: 0.02183    time: 0.4282  last_time: 0.4128  data_time: 0.0107  last_data_time: 0.0060   lr: 0.00025  max_mem: 2637M
# [03/16 11:22:21 d2.utils.events]:  eta: 3:32:22  iter: 2099  total_loss: 0.4219  loss_cls: 0.1151  loss_box_reg: 0.3041  loss_rpn_cls: 0.01056  loss_rpn_loc: 0.01435    time: 0.4300  last_time: 0.6676  data_time: 0.0187  last_data_time: 0.0228   lr: 0.00025  max_mem: 2638M
# [03/16 11:22:32 d2.utils.events]:  eta: 3:33:21  iter: 2119  total_loss: 0.6042  loss_cls: 0.2073  loss_box_reg: 0.3529  loss_rpn_cls: 0.01688  loss_rpn_loc: 0.02646    time: 0.4313  last_time: 0.4309  data_time: 0.0168  last_data_time: 0.0119   lr: 0.00025  max_mem: 2638M
# [03/16 11:22:42 d2.utils.events]:  eta: 3:32:36  iter: 2139  total_loss: 0.4886  loss_cls: 0.1494  loss_box_reg: 0.3178  loss_rpn_cls: 0.01301  loss_rpn_loc: 0.02025    time: 0.4317  last_time: 0.5803  data_time: 0.0117  last_data_time: 0.0284   lr: 0.00025  max_mem: 2638M
# [03/16 11:22:52 d2.utils.events]:  eta: 3:34:11  iter: 2159  total_loss: 0.5343  loss_cls: 0.1831  loss_box_reg: 0.3015  loss_rpn_cls: 0.009895  loss_rpn_loc: 0.02428    time: 0.4327  last_time: 0.4621  data_time: 0.0143  last_data_time: 0.0114   lr: 0.00025  max_mem: 2638M
# [03/16 11:23:02 d2.utils.events]:  eta: 3:33:00  iter: 2179  total_loss: 0.3712  loss_cls: 0.09688  loss_box_reg: 0.2677  loss_rpn_cls: 0.01254  loss_rpn_loc: 0.01476    time: 0.4332  last_time: 0.5999  data_time: 0.0110  last_data_time: 0.0284   lr: 0.00025  max_mem: 2638M
# [03/16 11:23:13 d2.utils.events]:  eta: 3:33:55  iter: 2199  total_loss: 0.4025  loss_cls: 0.1524  loss_box_reg: 0.273  loss_rpn_cls: 0.01592  loss_rpn_loc: 0.0187    time: 0.4339  last_time: 0.4643  data_time: 0.0132  last_data_time: 0.0073   lr: 0.00025  max_mem: 2638M
# [03/16 11:23:23 d2.utils.events]:  eta: 3:32:47  iter: 2219  total_loss: 0.427  loss_cls: 0.122  loss_box_reg: 0.2766  loss_rpn_cls: 0.01041  loss_rpn_loc: 0.01499    time: 0.4345  last_time: 0.5372  data_time: 0.0100  last_data_time: 0.0091   lr: 0.00025  max_mem: 2638M
# [03/16 11:23:32 d2.utils.events]:  eta: 3:32:38  iter: 2239  total_loss: 0.4563  loss_cls: 0.1642  loss_box_reg: 0.2494  loss_rpn_cls: 0.01656  loss_rpn_loc: 0.01043    time: 0.4350  last_time: 0.4526  data_time: 0.0126  last_data_time: 0.0172   lr: 0.00025  max_mem: 2638M
# [03/16 11:23:43 d2.utils.events]:  eta: 3:33:27  iter: 2259  total_loss: 0.5282  loss_cls: 0.1628  loss_box_reg: 0.3258  loss_rpn_cls: 0.01367  loss_rpn_loc: 0.02207    time: 0.4357  last_time: 0.6148  data_time: 0.0153  last_data_time: 0.0204   lr: 0.00025  max_mem: 2638M
# [03/16 11:23:53 d2.utils.events]:  eta: 3:33:22  iter: 2279  total_loss: 0.5503  loss_cls: 0.1466  loss_box_reg: 0.3167  loss_rpn_cls: 0.01438  loss_rpn_loc: 0.01963    time: 0.4362  last_time: 0.4324  data_time: 0.0131  last_data_time: 0.0059   lr: 0.00025  max_mem: 2638M
# [03/16 11:24:03 d2.utils.events]:  eta: 3:33:43  iter: 2299  total_loss: 0.5849  loss_cls: 0.1643  loss_box_reg: 0.3527  loss_rpn_cls: 0.01652  loss_rpn_loc: 0.0246    time: 0.4369  last_time: 0.6417  data_time: 0.0119  last_data_time: 0.0343   lr: 0.00025  max_mem: 2638M
# [03/16 11:24:12 d2.utils.events]:  eta: 3:33:10  iter: 2319  total_loss: 0.5899  loss_cls: 0.1889  loss_box_reg: 0.3453  loss_rpn_cls: 0.01191  loss_rpn_loc: 0.01649    time: 0.4372  last_time: 0.4173  data_time: 0.0117  last_data_time: 0.0062   lr: 0.00025  max_mem: 2638M
# [03/16 11:24:23 d2.utils.events]:  eta: 3:33:41  iter: 2339  total_loss: 0.7208  loss_cls: 0.2293  loss_box_reg: 0.3664  loss_rpn_cls: 0.02329  loss_rpn_loc: 0.03981    time: 0.4380  last_time: 0.6259  data_time: 0.0142  last_data_time: 0.0456   lr: 0.00025  max_mem: 2638M
# ...
# [03/16 15:43:00 d2.utils.events]:  eta: 0:09:43  iter: 28979  total_loss: 0.5343  loss_cls: 0.1726  loss_box_reg: 0.3137  loss_rpn_cls: 0.01466  loss_rpn_loc: 0.03232    time: 0.5695  last_time: 0.6677  data_time: 0.0128  last_data_time: 0.0193   lr: 0.00025  max_mem: 2641M
# [03/16 15:43:11 d2.utils.events]:  eta: 0:09:30  iter: 28999  total_loss: 0.6051  loss_cls: 0.1557  loss_box_reg: 0.3385  loss_rpn_cls: 0.02781  loss_rpn_loc: 0.02063    time: 0.5695  last_time: 0.5403  data_time: 0.0123  last_data_time: 0.0086   lr: 0.00025  max_mem: 2641M
# [03/16 15:43:23 d2.utils.events]:  eta: 0:09:22  iter: 29019  total_loss: 0.5607  loss_cls: 0.1687  loss_box_reg: 0.3399  loss_rpn_cls: 0.00834  loss_rpn_loc: 0.02309    time: 0.5695  last_time: 0.6352  data_time: 0.0116  last_data_time: 0.0277   lr: 0.00025  max_mem: 2641M
# [03/16 15:43:34 d2.utils.events]:  eta: 0:09:06  iter: 29039  total_loss: 0.4623  loss_cls: 0.1354  loss_box_reg: 0.2495  loss_rpn_cls: 0.009778  loss_rpn_loc: 0.01956    time: 0.5695  last_time: 0.6063  data_time: 0.0095  last_data_time: 0.0071   lr: 0.00025  max_mem: 2641M
# [03/16 15:43:46 d2.utils.events]:  eta: 0:08:59  iter: 29059  total_loss: 0.5291  loss_cls: 0.1448  loss_box_reg: 0.3058  loss_rpn_cls: 0.01542  loss_rpn_loc: 0.01991    time: 0.5695  last_time: 0.5395  data_time: 0.0133  last_data_time: 0.0068   lr: 0.00025  max_mem: 2641M
# [03/16 15:43:59 d2.utils.events]:  eta: 0:08:47  iter: 29079  total_loss: 0.6217  loss_cls: 0.2041  loss_box_reg: 0.3363  loss_rpn_cls: 0.0177  loss_rpn_loc: 0.03311    time: 0.5696  last_time: 0.6843  data_time: 0.0172  last_data_time: 0.0094   lr: 0.00025  max_mem: 2641M
# [03/16 15:44:12 d2.utils.events]:  eta: 0:08:36  iter: 29099  total_loss: 0.5663  loss_cls: 0.1552  loss_box_reg: 0.3153  loss_rpn_cls: 0.01961  loss_rpn_loc: 0.02178    time: 0.5696  last_time: 0.5322  data_time: 0.0170  last_data_time: 0.0062   lr: 0.00025  max_mem: 2641M
# [03/16 15:44:24 d2.utils.events]:  eta: 0:08:27  iter: 29119  total_loss: 0.5608  loss_cls: 0.1428  loss_box_reg: 0.318  loss_rpn_cls: 0.009854  loss_rpn_loc: 0.01632    time: 0.5696  last_time: 0.6863  data_time: 0.0135  last_data_time: 0.0288   lr: 0.00025  max_mem: 2641M
# [03/16 15:44:35 d2.utils.events]:  eta: 0:08:11  iter: 29139  total_loss: 0.4926  loss_cls: 0.1323  loss_box_reg: 0.3006  loss_rpn_cls: 0.007432  loss_rpn_loc: 0.01881    time: 0.5696  last_time: 0.5647  data_time: 0.0130  last_data_time: 0.0188   lr: 0.00025  max_mem: 2641M
# [03/16 15:44:48 d2.utils.events]:  eta: 0:08:04  iter: 29159  total_loss: 0.5523  loss_cls: 0.1859  loss_box_reg: 0.2699  loss_rpn_cls: 0.01623  loss_rpn_loc: 0.05147    time: 0.5696  last_time: 0.5266  data_time: 0.0197  last_data_time: 0.0079   lr: 0.00025  max_mem: 2641M
# [03/16 15:44:59 d2.utils.events]:  eta: 0:07:50  iter: 29179  total_loss: 0.5328  loss_cls: 0.1563  loss_box_reg: 0.3222  loss_rpn_cls: 0.01657  loss_rpn_loc: 0.01788    time: 0.5696  last_time: 0.6227  data_time: 0.0108  last_data_time: 0.0243   lr: 0.00025  max_mem: 2641M
# [03/16 15:45:10 d2.utils.events]:  eta: 0:07:37  iter: 29199  total_loss: 0.5067  loss_cls: 0.1547  loss_box_reg: 0.2977  loss_rpn_cls: 0.01321  loss_rpn_loc: 0.02406    time: 0.5696  last_time: 0.5173  data_time: 0.0132  last_data_time: 0.0081   lr: 0.00025  max_mem: 2641M
# [03/16 15:45:22 d2.utils.events]:  eta: 0:07:23  iter: 29219  total_loss: 0.5941  loss_cls: 0.1677  loss_box_reg: 0.3151  loss_rpn_cls: 0.01919  loss_rpn_loc: 0.05197    time: 0.5697  last_time: 0.6066  data_time: 0.0133  last_data_time: 0.0092   lr: 0.00025  max_mem: 2641M
# [03/16 15:45:35 d2.utils.events]:  eta: 0:07:12  iter: 29239  total_loss: 0.5218  loss_cls: 0.1494  loss_box_reg: 0.2769  loss_rpn_cls: 0.01313  loss_rpn_loc: 0.02605    time: 0.5697  last_time: 0.6432  data_time: 0.0147  last_data_time: 0.0083   lr: 0.00025  max_mem: 2641M
# [03/16 15:45:48 d2.utils.events]:  eta: 0:07:01  iter: 29259  total_loss: 0.4848  loss_cls: 0.1539  loss_box_reg: 0.2994  loss_rpn_cls: 0.01214  loss_rpn_loc: 0.01935    time: 0.5697  last_time: 0.5477  data_time: 0.0159  last_data_time: 0.0180   lr: 0.00025  max_mem: 2641M
# [03/16 15:45:59 d2.utils.events]:  eta: 0:06:50  iter: 29279  total_loss: 0.4921  loss_cls: 0.1499  loss_box_reg: 0.2698  loss_rpn_cls: 0.0215  loss_rpn_loc: 0.02638    time: 0.5698  last_time: 0.6483  data_time: 0.0145  last_data_time: 0.0139   lr: 0.00025  max_mem: 2641M
# [03/16 15:46:11 d2.utils.events]:  eta: 0:06:36  iter: 29299  total_loss: 0.5064  loss_cls: 0.1624  loss_box_reg: 0.2834  loss_rpn_cls: 0.01539  loss_rpn_loc: 0.02084    time: 0.5698  last_time: 0.5103  data_time: 0.0145  last_data_time: 0.0042   lr: 0.00025  max_mem: 2641M
# [03/16 15:46:23 d2.utils.events]:  eta: 0:06:28  iter: 29319  total_loss: 0.4786  loss_cls: 0.1354  loss_box_reg: 0.2782  loss_rpn_cls: 0.01297  loss_rpn_loc: 0.02569    time: 0.5698  last_time: 0.5514  data_time: 0.0141  last_data_time: 0.0086   lr: 0.00025  max_mem: 2641M
# [03/16 15:46:34 d2.utils.events]:  eta: 0:06:15  iter: 29339  total_loss: 0.4714  loss_cls: 0.1652  loss_box_reg: 0.2644  loss_rpn_cls: 0.01919  loss_rpn_loc: 0.02695    time: 0.5698  last_time: 0.6911  data_time: 0.0106  last_data_time: 0.0258   lr: 0.00025  max_mem: 2641M
# [03/16 15:46:46 d2.utils.events]:  eta: 0:06:03  iter: 29359  total_loss: 0.4738  loss_cls: 0.1466  loss_box_reg: 0.2996  loss_rpn_cls: 0.01831  loss_rpn_loc: 0.01193    time: 0.5698  last_time: 0.5118  data_time: 0.0142  last_data_time: 0.0077   lr: 0.00025  max_mem: 2641M
# [03/16 15:47:01 d2.utils.events]:  eta: 0:05:56  iter: 29379  total_loss: 0.5672  loss_cls: 0.1755  loss_box_reg: 0.338  loss_rpn_cls: 0.01853  loss_rpn_loc: 0.04362    time: 0.5699  last_time: 0.6504  data_time: 0.0235  last_data_time: 0.0293   lr: 0.00025  max_mem: 2641M
# [03/16 15:47:12 d2.utils.events]:  eta: 0:05:42  iter: 29399  total_loss: 0.4368  loss_cls: 0.1225  loss_box_reg: 0.2586  loss_rpn_cls: 0.007785  loss_rpn_loc: 0.02044    time: 0.5699  last_time: 0.5240  data_time: 0.0136  last_data_time: 0.0049   lr: 0.00025  max_mem: 2641M
# [03/16 15:47:25 d2.utils.events]:  eta: 0:05:33  iter: 29419  total_loss: 0.4563  loss_cls: 0.1585  loss_box_reg: 0.2715  loss_rpn_cls: 0.01386  loss_rpn_loc: 0.01442    time: 0.5699  last_time: 0.5123  data_time: 0.0185  last_data_time: 0.0070   lr: 0.00025  max_mem: 2641M
# [03/16 15:47:36 d2.utils.events]:  eta: 0:05:19  iter: 29439  total_loss: 0.4393  loss_cls: 0.1579  loss_box_reg: 0.2537  loss_rpn_cls: 0.01493  loss_rpn_loc: 0.02293    time: 0.5699  last_time: 0.6932  data_time: 0.0098  last_data_time: 0.0385   lr: 0.00025  max_mem: 2641M
# [03/16 15:47:48 d2.utils.events]:  eta: 0:05:08  iter: 29459  total_loss: 0.5229  loss_cls: 0.1628  loss_box_reg: 0.3295  loss_rpn_cls: 0.01332  loss_rpn_loc: 0.02557    time: 0.5699  last_time: 0.5265  data_time: 0.0137  last_data_time: 0.0145   lr: 0.00025  max_mem: 2641M
# [03/16 15:48:00 d2.utils.events]:  eta: 0:04:58  iter: 29479  total_loss: 0.561  loss_cls: 0.1528  loss_box_reg: 0.3291  loss_rpn_cls: 0.007926  loss_rpn_loc: 0.01452    time: 0.5700  last_time: 0.7274  data_time: 0.0144  last_data_time: 0.0316   lr: 0.00025  max_mem: 2641M
# [03/16 15:48:11 d2.utils.events]:  eta: 0:04:43  iter: 29499  total_loss: 0.5797  loss_cls: 0.1547  loss_box_reg: 0.3223  loss_rpn_cls: 0.01553  loss_rpn_loc: 0.02913    time: 0.5700  last_time: 0.5108  data_time: 0.0105  last_data_time: 0.0060   lr: 0.00025  max_mem: 2641M
# [03/16 15:48:23 d2.utils.events]:  eta: 0:04:31  iter: 29519  total_loss: 0.4819  loss_cls: 0.1252  loss_box_reg: 0.3231  loss_rpn_cls: 0.01821  loss_rpn_loc: 0.02408    time: 0.5700  last_time: 0.5419  data_time: 0.0204  last_data_time: 0.0068   lr: 0.00025  max_mem: 2641M
# [03/16 15:48:34 d2.utils.events]:  eta: 0:04:19  iter: 29539  total_loss: 0.4381  loss_cls: 0.1234  loss_box_reg: 0.2694  loss_rpn_cls: 0.0111  loss_rpn_loc: 0.02542    time: 0.5700  last_time: 0.6455  data_time: 0.0097  last_data_time: 0.0084   lr: 0.00025  max_mem: 2641M
# [03/16 15:48:46 d2.utils.events]:  eta: 0:04:08  iter: 29559  total_loss: 0.5542  loss_cls: 0.1547  loss_box_reg: 0.3077  loss_rpn_cls: 0.01584  loss_rpn_loc: 0.01831    time: 0.5700  last_time: 0.5058  data_time: 0.0153  last_data_time: 0.0088   lr: 0.00025  max_mem: 2641M
# [03/16 15:48:57 d2.utils.events]:  eta: 0:03:57  iter: 29579  total_loss: 0.477  loss_cls: 0.1389  loss_box_reg: 0.2576  loss_rpn_cls: 0.01356  loss_rpn_loc: 0.02255    time: 0.5700  last_time: 0.6033  data_time: 0.0102  last_data_time: 0.0088   lr: 0.00025  max_mem: 2641M
# [03/16 15:49:08 d2.utils.events]:  eta: 0:03:45  iter: 29599  total_loss: 0.5341  loss_cls: 0.1516  loss_box_reg: 0.334  loss_rpn_cls: 0.0175  loss_rpn_loc: 0.0217    time: 0.5700  last_time: 0.4972  data_time: 0.0113  last_data_time: 0.0065   lr: 0.00025  max_mem: 2641M
# [03/16 15:49:21 d2.utils.events]:  eta: 0:03:34  iter: 29619  total_loss: 0.5698  loss_cls: 0.1586  loss_box_reg: 0.2756  loss_rpn_cls: 0.01319  loss_rpn_loc: 0.02279    time: 0.5700  last_time: 0.5656  data_time: 0.0192  last_data_time: 0.0170   lr: 0.00025  max_mem: 2641M
# [03/16 15:49:32 d2.utils.events]:  eta: 0:03:23  iter: 29639  total_loss: 0.4551  loss_cls: 0.1459  loss_box_reg: 0.2957  loss_rpn_cls: 0.01042  loss_rpn_loc: 0.01746    time: 0.5700  last_time: 0.7196  data_time: 0.0111  last_data_time: 0.0325   lr: 0.00025  max_mem: 2641M
# [03/16 15:49:44 d2.utils.events]:  eta: 0:03:12  iter: 29659  total_loss: 0.5618  loss_cls: 0.1668  loss_box_reg: 0.3112  loss_rpn_cls: 0.01876  loss_rpn_loc: 0.02771    time: 0.5700  last_time: 0.6533  data_time: 0.0160  last_data_time: 0.0295   lr: 0.00025  max_mem: 2641M
# [03/16 15:49:58 d2.utils.events]:  eta: 0:03:02  iter: 29679  total_loss: 0.4675  loss_cls: 0.1281  loss_box_reg: 0.3138  loss_rpn_cls: 0.01208  loss_rpn_loc: 0.0152    time: 0.5701  last_time: 0.6815  data_time: 0.0203  last_data_time: 0.0417   lr: 0.00025  max_mem: 2641M
# [03/16 15:50:09 d2.utils.events]:  eta: 0:02:49  iter: 29699  total_loss: 0.5112  loss_cls: 0.1507  loss_box_reg: 0.2898  loss_rpn_cls: 0.01541  loss_rpn_loc: 0.01898    time: 0.5701  last_time: 0.5509  data_time: 0.0093  last_data_time: 0.0073   lr: 0.00025  max_mem: 2641M
# [03/16 15:50:21 d2.utils.events]:  eta: 0:02:38  iter: 29719  total_loss: 0.3935  loss_cls: 0.1165  loss_box_reg: 0.2065  loss_rpn_cls: 0.008395  loss_rpn_loc: 0.02499    time: 0.5701  last_time: 0.5333  data_time: 0.0160  last_data_time: 0.0075   lr: 0.00025  max_mem: 2641M
# [03/16 15:50:32 d2.utils.events]:  eta: 0:02:27  iter: 29739  total_loss: 0.4336  loss_cls: 0.1311  loss_box_reg: 0.2627  loss_rpn_cls: 0.007478  loss_rpn_loc: 0.02458    time: 0.5701  last_time: 0.6307  data_time: 0.0103  last_data_time: 0.0091   lr: 0.00025  max_mem: 2641M
# [03/16 15:50:44 d2.utils.events]:  eta: 0:02:15  iter: 29759  total_loss: 0.4545  loss_cls: 0.1311  loss_box_reg: 0.3004  loss_rpn_cls: 0.01283  loss_rpn_loc: 0.01598    time: 0.5701  last_time: 0.5672  data_time: 0.0116  last_data_time: 0.0173   lr: 0.00025  max_mem: 2641M
# [03/16 15:50:56 d2.utils.events]:  eta: 0:02:04  iter: 29779  total_loss: 0.564  loss_cls: 0.1679  loss_box_reg: 0.334  loss_rpn_cls: 0.01827  loss_rpn_loc: 0.02497    time: 0.5701  last_time: 0.6503  data_time: 0.0150  last_data_time: 0.0223   lr: 0.00025  max_mem: 2641M
# [03/16 15:51:07 d2.utils.events]:  eta: 0:01:52  iter: 29799  total_loss: 0.353  loss_cls: 0.1257  loss_box_reg: 0.2538  loss_rpn_cls: 0.006345  loss_rpn_loc: 0.01073    time: 0.5701  last_time: 0.5486  data_time: 0.0083  last_data_time: 0.0066   lr: 0.00025  max_mem: 2641M
# [03/16 15:51:19 d2.utils.events]:  eta: 0:01:41  iter: 29819  total_loss: 0.3941  loss_cls: 0.1385  loss_box_reg: 0.2537  loss_rpn_cls: 0.009399  loss_rpn_loc: 0.01138    time: 0.5701  last_time: 0.5157  data_time: 0.0161  last_data_time: 0.0019   lr: 0.00025  max_mem: 2641M
# [03/16 15:51:30 d2.utils.events]:  eta: 0:01:30  iter: 29839  total_loss: 0.5767  loss_cls: 0.1441  loss_box_reg: 0.3682  loss_rpn_cls: 0.0165  loss_rpn_loc: 0.01918    time: 0.5701  last_time: 0.6316  data_time: 0.0116  last_data_time: 0.0077   lr: 0.00025  max_mem: 2641M
# [03/16 15:51:41 d2.utils.events]:  eta: 0:01:18  iter: 29859  total_loss: 0.4473  loss_cls: 0.1242  loss_box_reg: 0.2635  loss_rpn_cls: 0.01251  loss_rpn_loc: 0.02391    time: 0.5701  last_time: 0.5221  data_time: 0.0140  last_data_time: 0.0090   lr: 0.00025  max_mem: 2641M
# [03/16 15:51:54 d2.utils.events]:  eta: 0:01:07  iter: 29879  total_loss: 0.656  loss_cls: 0.2014  loss_box_reg: 0.3946  loss_rpn_cls: 0.02331  loss_rpn_loc: 0.03621    time: 0.5702  last_time: 0.5827  data_time: 0.0169  last_data_time: 0.0117   lr: 0.00025  max_mem: 2641M
# [03/16 15:52:04 d2.utils.events]:  eta: 0:00:56  iter: 29899  total_loss: 0.4443  loss_cls: 0.1418  loss_box_reg: 0.2534  loss_rpn_cls: 0.0109  loss_rpn_loc: 0.02343    time: 0.5701  last_time: 0.6555  data_time: 0.0087  last_data_time: 0.0135   lr: 0.00025  max_mem: 2641M
# [03/16 15:52:17 d2.utils.events]:  eta: 0:00:45  iter: 29919  total_loss: 0.4801  loss_cls: 0.1729  loss_box_reg: 0.248  loss_rpn_cls: 0.01154  loss_rpn_loc: 0.02635    time: 0.5702  last_time: 0.5163  data_time: 0.0149  last_data_time: 0.0061   lr: 0.00025  max_mem: 2641M
# [03/16 15:52:28 d2.utils.events]:  eta: 0:00:33  iter: 29939  total_loss: 0.5934  loss_cls: 0.1746  loss_box_reg: 0.2939  loss_rpn_cls: 0.02189  loss_rpn_loc: 0.02597    time: 0.5702  last_time: 0.5818  data_time: 0.0118  last_data_time: 0.0067   lr: 0.00025  max_mem: 2641M
# [03/16 15:52:40 d2.utils.events]:  eta: 0:00:22  iter: 29959  total_loss: 0.5551  loss_cls: 0.1675  loss_box_reg: 0.3205  loss_rpn_cls: 0.01155  loss_rpn_loc: 0.01986    time: 0.5702  last_time: 0.6281  data_time: 0.0127  last_data_time: 0.0080   lr: 0.00025  max_mem: 2641M
# [03/16 15:52:54 d2.utils.events]:  eta: 0:00:11  iter: 29979  total_loss: 0.4018  loss_cls: 0.1131  loss_box_reg: 0.2408  loss_rpn_cls: 0.009477  loss_rpn_loc: 0.0208    time: 0.5703  last_time: 0.5037  data_time: 0.0196  last_data_time: 0.0013   lr: 0.00025  max_mem: 2641M
# [03/16 15:53:12 d2.utils.events]:  eta: 0:00:00  iter: 29999  total_loss: 0.4741  loss_cls: 0.1183  loss_box_reg: 0.3176  loss_rpn_cls: 0.009159  loss_rpn_loc: 0.01905    time: 0.5702  last_time: 0.6637  data_time: 0.0097  last_data_time: 0.0166   lr: 0.00025  max_mem: 2641M
# [03/16 15:53:12 d2.engine.hooks]: Overall training speed: 29998 iterations in 4:45:06 (0.5703 s / it)
# [03/16 15:53:12 d2.engine.hooks]: Total training time: 4:46:05 (0:00:58 on hooks)
# [03/16 15:53:13 d2.data.datasets.coco]: Loaded 5000 images in COCO format from instances_val2017_5labels.json
# [03/16 15:53:13 d2.data.build]: Distribution of instances among all 5 categories:
# |  category  | #instances   |   category    | #instances   |  category  | #instances   |
# |:----------:|:-------------|:-------------:|:-------------|:----------:|:-------------|
# |    car     | 1918         |     chair     | 1771         |    cup     | 895          |
# |   person   | 10777        | traffic light | 634          |            |              |
# |   total    | 15995        |               |              |            |              |
# [03/16 15:53:13 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [03/16 15:53:13 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [03/16 15:53:13 d2.data.common]: Serializing 5000 elements to byte tensors and concatenating them all ...
# [03/16 15:53:14 d2.data.common]: Serialized dataset takes 9.72 MiB
# WARNING [03/16 15:53:14 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.

# %% [markdown]
# ## Inference & evaluation using the trained model
# If you wish to load a trained model to run inference

# %%
evaluator = COCOEvaluator("my_dataset_val", output_dir="/content/output")
val_loader = build_detection_test_loader(cfg, "my_dataset_val")
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")  # path to the model we just trained
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7   # set a custom testing threshold
predictor = DefaultPredictor(cfg)
# Out:
# [03/16 15:54:55 d2.data.datasets.coco]: Loaded 5000 images in COCO format from instances_val2017_5labels.json
# [03/16 15:54:55 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [03/16 15:54:55 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [03/16 15:54:55 d2.data.common]: Serializing 5000 elements to byte tensors and concatenating them all ...
# [03/16 15:54:55 d2.data.common]: Serialized dataset takes 9.72 MiB
# [03/16 15:54:57 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/model_final.pth ...

# %% [markdown]
# The code below defines a function "format_detectron2_predictions" to convert the prediction output of Detectron2 to a format that can be used by Cleanlab for identifying label errors. This function accepts the predicted object instances and the number of classes as inputs. It processes the predicted bounding boxes and prediction-confidence for each instance, and outputs a list of numpy arrays containing the bounding boxes and prediction-confidence for each class.

# %%
def format_detectron2_predictions(ins,num_classes):
    fields = ins.get_fields()
    boxes = fields['pred_boxes'].tensor.numpy()
    res = [[] for i in range(num_classes)]
    for i in range(0,len(fields['pred_classes'])):
        pred_class = fields['pred_classes'][i].item()
        probs = ins.get_fields()['scores'][i].item()
        box_cord = list(boxes[i])
        box_cord.append(probs)
        res[pred_class].append(box_cord)
    res2 = []
    for i in res:
        if len(i)==0:
            q = np.array(i,dtype=np.float32).reshape((0,num_classes))
        else:
            q = np.array(i,dtype=np.float32)
        res2.append(q)
    return res2

# %% [markdown]
# To perform inference and testing on the tutorial notebook linked here, we utilize a limited portion of the validation set of COCO 2017. To find label errors in this subset, please run our [tutorial](https://docs.cleanlab.ai/stable/index.html) notebook on [Finding Label Errors in Object Detection Datasets](https://github.com/cleanlab/cleanlab/blob/master/docs/source/tutorials/object_detection.ipynb).

# %%
labels = pickle.load(open("labels.pkl",'rb'))
results = []
for i in labels:
    im_name = os.path.join(VAL_PATH, i['seg_map'].replace(".png",'.jpg'))
    im = cv2.imread(im_name)
    outputs = predictor(im)
    results.append(format_detectron2_predictions(outputs["instances"].to("cpu"),cfg.MODEL.ROI_HEADS.NUM_CLASSES))

pickle.dump(results,open("predictions.pkl",'wb'))

# %%
from google.colab import files

# Specify the file path you want to download
file_path = "/content/output/model_final.pth"

# Use the files.download function to download the file
files.download(file_path)
